# %%
import pickle

# %%
sc = pickle.load(open("Scaler.sav","rb"))

# %%
preinput=sc.transform([[13000,12000,4000,0,1]])
# Out:
# C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
loaded_model=pickle.load(open("finalized_model_preprocess_input.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([107675.76875584])
