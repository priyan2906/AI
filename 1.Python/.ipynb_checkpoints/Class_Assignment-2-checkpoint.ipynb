# %%
from importlib import reload
import assignment
reload(assignment)
# Out:
# <module 'assignment' from 'C:\\Users\\Priyan\\Hope\\AI\\Python\\assignment.py'>

# %%
from assignment import Assignment

# %%
Assignment.subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
Assignment.oddEven()
# Out:
# Enter a number:  43
# Enter a number: 43
# 43 is Odd number

# %%
Assignment.eligible()
# Out:
# Your Gender:  Male
# Your Gender: Male
# Your Age:  20
# Your Age: 20
# NOT ELIGIBLE

# %%
Assignment.percentage()
# Out:
# Subject1 =  98
# Subject1 = 98
# Subject2 =  97
# Subject2 = 97
# Subject3 =  87
# Subject3 = 87
# Subject4 =  90
# Subject4 = 90
# Subject5 =  89
# Subject5 = 89
# Total = 461
# Percentage = 92.2

# %%
Assignment.triangle()
# Out:
# Height:  32
# Height: 32
# Breadth:  34
# Breadth: 34
# Area formula: (Height * Breadth)/2
# Area of Triangle: 544.0
# Height1:  2
# Height1: 2
# Height2:  4
# Height2: 4
# Breadth:  4
# Breadth: 4
# Perimeter formula: Height1 + Height2 + Breadth
# Perimeter of Triangle: 10
