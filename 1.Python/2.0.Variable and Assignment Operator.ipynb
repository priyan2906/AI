# %%
Num1=50
Num2=50
add=Num1+Num2
sub=Num1-Num2
print(add)
print(sub)
# Out:
# 100
# 0

# %%
Num1=50
Num2=50
add=Num1+Num2
print("The addition of two numbers")
print("The number 1:",Num1)
print("The number 2:",Num2)
print("The answer:",add)
# Out:
# The addition of two numbers
# The number 1: 50
# The number 2: 50
# The answer: 100

# %%
Num1=50
Num2=50
add=Num1+Num2
print(f"""The addition of two numbers 
The number 1:{Num1} 
The number 2:{Num2} 
The answer:{add}""")
# Out:
# The addition of two numbers
# The number 1:50
# The number 2:50
# The answer:100
