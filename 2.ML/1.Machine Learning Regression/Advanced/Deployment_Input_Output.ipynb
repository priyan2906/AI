# %%
# Save scalers
import pickle
# Later, in another file
sc = pickle.load(open("scaler_X.sav", 'rb'))
scy = pickle.load(open("scaler_y.sav", 'rb'))

# %%
preinput=sc.transform([[13000,12000,4000,0,1]])
# Out:
# C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
loaded_model=pickle.load(open("finalized_model_pre_in_out.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([-1.01154876])

# %%
preout=scy.inverse_transform([result])

# %%
preout
# Out:
# array([[66715.81485064]])
