# %%
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0         True
# 1     35            20000          0         True
# 2     26            43000          0        False
# 3     27            57000          0        False
# 4     19            76000          0         True
# ..   ...              ...        ...          ...
# 395   46            41000          1        False
# 396   51            23000          1         True
# 397   50            20000          1        False
# 398   36            33000          0         True
# 399   49            36000          1        False
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
indep=dataset[["Age","EstimatedSalary","Gender_Male"]]
dep=dataset["Purchased"]

# %%
indep.shape
# Out:
# (400, 3)

# %%
dep
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'penalty':['l1', 'l2', 'elasticnet', None],
              'C':[1.0,100.0,1000.0,5000.0]
} 

grid = GridSearchCV(LogisticRegression(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1') 
   
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\linear_model\_logistic.py", line 63, in _check_solver
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\linear_model\_logistic.py", line 63, in _check_solver
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [       nan 0.73619281        nan 0.73619281        nan 0.73619281
#         nan 0.73619281        nan 0.73619281        nan 0.73619281
#         nan 0.72222222        nan 0.73619281]
#   warnings.warn(
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [1.0, 100.0, 1000.0, 5000.0],
#                          'penalty': ['l1', 'l2', 'elasticnet', None]},
#              scoring='f1', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
   
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 1.0, 'penalty': 'l2'}: 0.8872628037179481

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[79  6]
#  [ 9 40]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91        85
#            1       0.87      0.82      0.84        49
#
#     accuracy                           0.89       134
#    macro avg       0.88      0.87      0.88       134
# weighted avg       0.89      0.89      0.89       134

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# np.float64(0.9510204081632653)

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.002379      0.000598         0.000000        0.000000      1.0
# 1        0.022689      0.004339         0.007347        0.001342      1.0
# 2        0.002102      0.000665         0.000000        0.000000      1.0
# 3        0.019078      0.004331         0.006188        0.000980      1.0
# 4        0.001196      0.000258         0.000000        0.000000    100.0
# 5        0.019496      0.001278         0.006791        0.000888    100.0
# 6        0.001312      0.000337         0.000000        0.000000    100.0
# 7        0.020596      0.001666         0.005082        0.000430    100.0
# 8        0.001173      0.000189         0.000000        0.000000   1000.0
# 9        0.016186      0.001946         0.005029        0.000625   1000.0
# 10       0.001050      0.000179         0.000000        0.000000   1000.0
# 11       0.016701      0.004497         0.004927        0.000756   1000.0
# 12       0.001173      0.000340         0.000000        0.000000   5000.0
# 13       0.015187      0.001787         0.004161        0.000849   5000.0
# 14       0.001207      0.000290         0.000000        0.000000   5000.0
# 15       0.018127      0.001114         0.004537        0.000226   5000.0
#
#    param_penalty                                  params  split0_test_score  \
# 0             l1             {'C': 1.0, 'penalty': 'l1'}                NaN
# 1             l2             {'C': 1.0, 'penalty': 'l2'}             0.6875
# 2     elasticnet     {'C': 1.0, 'penalty': 'elasticnet'}                NaN
# 3           None             {'C': 1.0, 'penalty': None}             0.6875
# 4             l1           {'C': 100.0, 'penalty': 'l1'}                NaN
# 5             l2           {'C': 100.0, 'penalty': 'l2'}             0.6875
# 6     elasticnet   {'C': 100.0, 'penalty': 'elasticnet'}                NaN
# 7           None           {'C': 100.0, 'penalty': None}             0.6875
# 8             l1          {'C': 1000.0, 'penalty': 'l1'}                NaN
# 9             l2          {'C': 1000.0, 'penalty': 'l2'}             0.6875
# 10    elasticnet  {'C': 1000.0, 'penalty': 'elasticnet'}                NaN
# 11          None          {'C': 1000.0, 'penalty': None}             0.6875
# 12            l1          {'C': 5000.0, 'penalty': 'l1'}                NaN
# 13            l2          {'C': 5000.0, 'penalty': 'l2'}             0.6875
# 14    elasticnet  {'C': 5000.0, 'penalty': 'elasticnet'}                NaN
# 15          None          {'C': 5000.0, 'penalty': None}             0.6875
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1            0.722222                0.5           0.888889
# 2                 NaN                NaN                NaN
# 3            0.722222                0.5           0.888889
# 4                 NaN                NaN                NaN
# 5            0.722222                0.5           0.888889
# 6                 NaN                NaN                NaN
# 7            0.722222                0.5           0.888889
# 8                 NaN                NaN                NaN
# 9            0.722222                0.5           0.888889
# 10                NaN                NaN                NaN
# 11           0.722222                0.5           0.888889
# 12                NaN                NaN                NaN
# 13           0.722222                0.5           0.888889
# 14                NaN                NaN                NaN
# 15           0.722222                0.5           0.888889
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                9
# 1            0.882353         0.736193        0.143549                1
# 2                 NaN              NaN             NaN                9
# 3            0.882353         0.736193        0.143549                1
# 4                 NaN              NaN             NaN                9
# 5            0.882353         0.736193        0.143549                1
# 6                 NaN              NaN             NaN                9
# 7            0.882353         0.736193        0.143549                1
# 8                 NaN              NaN             NaN                9
# 9            0.882353         0.736193        0.143549                1
# 10                NaN              NaN             NaN                9
# 11           0.882353         0.736193        0.143549                1
# 12                NaN              NaN             NaN                9
# 13           0.812500         0.722222        0.131542                8
# 14                NaN              NaN             NaN                9
# 15           0.882353         0.736193        0.143549                1

# %%
age_input=float(input("Age:"))
bmi_input=float(input("EstimatedSalary:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
# Out:
# Age: 31
# EstimatedSalary: 150000
# Sex Male 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,sex_male_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]
# C:\Users\Priyan\anaconda3\envs\aiml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
